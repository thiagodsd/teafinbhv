# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/weights0.csv')
df
# Out:
#                                              question  \
# 0                                         Você poupa?
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                     Para que poupa?
# 5                                                 NaN
# 6                                                 NaN
# 7                       Você poupa o máximo que pode?
# 8                                                 NaN
# 9                                                 NaN
# 10                           O que você usa do banco?
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                  Você entende os produtos que usa?
# 16                                                NaN
# 17                                                NaN
# 18  Os produtos que você usa representam quanto do...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                      Você paga suas contas em dia?
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Quanto tempo você demoraria para pagar suas pa...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Suas contas fixas represetam quanto do seu sal...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                             Você tem algum seguro?
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                      Você gasta mais do que ganha?
# 40                                                NaN
# 41                  Como você organiza suas finanças?
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                           Você tem muitas dívidas?
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
#
#                                   answer    w0    w1    w2    w3    w4 button
# 0                                 Sempre  0.00  0.10  0.20  0.50  0.70      r
# 1                               Às vezes  0.10  0.40  0.40  0.30  0.20    NaN
# 2                              Raramente  0.30  0.30  0.30  0.20  0.10    NaN
# 3                                  Nunca  0.60  0.20  0.10  0.00  0.00    NaN
# 4                  Reserva de emergencia  0.00  0.00  0.10  0.10  0.20      r
# 5                        Realizar sonhos  0.10  0.10  0.30  0.40  0.50    NaN
# 6                    Previdência privada  0.00  0.00  0.10  0.20  0.30    NaN
# 7                Poupo o máximo possível  0.40  0.40  0.20  0.50  0.60      r
# 8                   Poderia guardar mais  0.20  0.30  0.30  0.30  0.40    NaN
# 9   Poderia começar a guardar mais vezes  0.40  0.30  0.50  0.20  0.00    NaN
# 10                       Cheque especial  0.40  0.30  0.20  0.10  0.00      c
# 11                                Cartão  0.10  0.08  0.02  0.08  0.10    NaN
# 12                            Empréstimo  0.30  0.20  0.10  0.05  0.05    NaN
# 13                             Consórcio  0.05  0.20  0.30  0.35  0.10    NaN
# 14                         Financiamento  0.20  0.30  0.35  0.10  0.05    NaN
# 15                    Entendo exatamente  0.00  0.20  0.30  0.50  0.80      r
# 16                         Mais ou menos  0.20  0.50  0.40  0.30  0.20    NaN
# 17                   Não entendo direito  0.80  0.30  0.30  0.20  0.00    NaN
# 18                                    0%  0.00  0.00  0.10  0.30  0.60      r
# 19                                   25%  0.00  0.10  0.20  0.40  0.50    NaN
# 20                                   50%  0.25  0.20  0.20  0.15  0.15    NaN
# 21                                   75%  0.40  0.30  0.25  0.15  0.05    NaN
# 22                                  100%  0.60  0.50  0.20  0.00  0.00    NaN
# 23                                Sempre  0.00  0.10  0.20  0.50  0.70      r
# 24                          Quase sempre  0.10  0.40  0.40  0.30  0.20    NaN
# 25                             Raramente  0.30  0.30  0.30  0.20  0.10    NaN
# 26                                 Nunca  0.60  0.20  0.10  0.00  0.00    NaN
# 27                                 1 mês  0.00  0.10  0.20  0.50  0.70      r
# 28                               6 meses  0.10  0.40  0.40  0.30  0.20    NaN
# 29                                 1 ano  0.30  0.30  0.30  0.20  0.10    NaN
# 30                        5 anos ou mais  0.60  0.20  0.10  0.00  0.00    NaN
# 31                          50% ou menos  0.00  0.00  0.20  0.30  0.60      r
# 32                                   70%  0.10  0.30  0.30  0.50  0.30    NaN
# 33                                   90%  0.30  0.30  0.30  0.20  0.10    NaN
# 34                                  100%  0.60  0.40  0.20  0.00  0.00    NaN
# 35                                Imóvel  0.00  0.00  0.10  0.30  0.30      r
# 36                               Veículo  0.00  0.10  0.10  0.40  0.40    NaN
# 37                                  Vida  0.00  0.00  0.10  0.30  0.40    NaN
# 38                       Convênio médico  0.10  0.10  0.20  0.40  0.60    NaN
# 39                                   Sim  0.80  0.70  0.30  0.20  0.10      r
# 40                                   Não  0.20  0.30  0.70  0.80  0.90    NaN
# 41                       Com aplicativos  0.00  0.10  0.40  0.50  0.60      c
# 42               Planilhas no computador  0.10  0.20  0.30  0.50  0.70    NaN
# 43                             Anotações  0.10  0.20  0.30  0.50  0.40    NaN
# 44                          Não organizo  0.80  0.50  0.20  0.10  0.00    NaN
# 45                             Não tenho  0.10  0.30  0.50  0.60  0.70      r
# 46           Sim, mas estão sob controle  0.40  0.60  0.50  0.40  0.30    NaN
# 47            Sim e estão me complicando  0.40  0.40  0.30  0.20  0.00    NaN
# 48            Sim e não sei o que fazer!  0.50  0.10  0.00  0.00  0.00    NaN

# %%
d = dict()

QUESTION = str()
INDEX    = int()

for i,r in df.iterrows():
    if str(r['question']) != 'nan':
        INDEX    = str(i).zfill(3)
        d[INDEX] = dict()
        d[INDEX]['question']   = r['question']
        d[INDEX]['answers'] = [ [r['answer'], [float(r['w0']),
                                                 float(r['w1']),
                                                 float(r['w2']),
                                                 float(r['w3']),
                                                 float(r['w4'])] 
                                   ] 
                                 ]
    else:
        d[INDEX]['answers'].append( [r['answer'], [float(r['w0']),
                                                 float(r['w1']),
                                                 float(r['w2']),
                                                 float(r['w3']),
                                                 float(r['w4'])] 
                                   ]  )

# %%
with open('quizquestions.js', 'w') as qq:
    for k in sorted(d):
        qq.write(
"""
{{
      question: "{}",
      answers: {{
""".format(d[k]['question']))

                
        for i,v in enumerate(d[k]['answers']):
            if i < len(d[k]['answers'])-1:
                qq.write(
"""
        {}:"{}",
""".format(str(i), v[0]))
            else:
                qq.write(
"""
        {}:"{}" }},
""".format(str(i), v[0]))
        
        qq.write(
"""
      weights: [
""")
                
        for i,v in enumerate(d[k]['answers']):
            if i < len(d[k]['answers'])-1:
                qq.write(
"""
                    {},
""".format(repr(v[1])))
            else:
                qq.write(
"""
                    {} ],
      img: "pig"
    }},
""".format(repr(v[1])))
